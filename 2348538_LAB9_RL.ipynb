# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_states = 6
start_action = 0
terminal_state = n_states - 1
rewards = np.array([-1, -1, -1, 1, 0, -1])

# %%
def take_action(state):
    return state + 1 if state < terminal_state else state

# %%
alpha = 0.1 
gamma = 0.9
n_episodes = 1000

# %%
V = np.zeros(n_states)

for episode in range(n_episodes):
    state = start_action
    while state != terminal_state:
        next_state = take_action(state)
        # TD(0) update
        V[state] += alpha * (rewards[next_state] + gamma * V[next_state] - V[state])
        state = next_state

# %%
print("State Value Estimates after Training : ")
for i, value in enumerate(V):
    print(f'State {i}: {value:.2f}')
# Out:
# State Value Estimates after Training :
# State 0: 0.66
# State 1: 0.73
# State 2: 0.81
# State 3: 0.90
# State 4: 1.00
# State 5: 0.00

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(n_states), V, marker="o", linestyle="-", color="b")
plt.title("State-Value Estimates (TD(0))")
plt.xlabel("State")
plt.ylabel("Value Estimate")
plt.grid()
plt.show()
